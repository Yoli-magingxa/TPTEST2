# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("C:\\Users\\cash\\Downloads\\Informal_Settlement_Programme_-1898186875815614491.csv")


def selectionSort(sort_est_hhc):
    n= len(sort_est_hhc)
    for i in range(n):
        min_index = i
        for j in range(i+1,n):
            if sort_est_hhc[j] < sort_est_hhc[min_index]:
                min_index = j
        temp = sort_est_hhc[i]
        sort_est_hhc[i] = sort_est_hhc[min_index]
        sort_est_hhc[min_index]=temp
sort_est_hhc = df['EST_HHC']
est_hhc_list = sort_est_hhc.tolist()
selectionSort(sort_est_hhc)

sorted_df = df.copy()
sorted_df['EST_HHC'] = est_hhc_list
print("Sorted Column : EST_HHC ")
print(sorted_df)

def binarty_serach(my_arr , target):
    left,right =0,len(my_arr)-1
    while left <= right :
# Out:
# C:\Users\cash\AppData\Local\Temp\ipykernel_15424\2306523505.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sort_est_hhc[i] = sort_est_hhc[min_index]
# C:\Users\cash\AppData\Local\Temp\ipykernel_15424\2306523505.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sort_est_hhc[min_index]=temp
# C:\Users\cash\AppData\Local\Temp\ipykernel_15424\2306523505.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
